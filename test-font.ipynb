# %%
from PIL import Image, ImageFont, ImageDraw
import os

# %%
def test_font(font_dir):
  image_width = 500
  image_height = 1500
  image = Image.new('RGB', (image_width, image_height,), '#fff')
  draw = ImageDraw.Draw(image)

  fonts = [f for f in os.listdir(font_dir) if f.endswith('.ttf')]
  fonts.sort()
  curr_y = 10
  for font_name in fonts:
    font = ImageFont.truetype(f'{font_dir}/{font_name}', 20)
    draw.text((10, curr_y), font_name + ' เก้าสิบห้าร้อยสามสิบ', font=font, fill='#000')
    text_height = font.getsize(font_name)[1] + 5
    curr_y += text_height
  return image

# %%
test_font('handwriting')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/rk/cgmwyjj17ddfrn5d_vqzdyr00000gn/T/ipykernel_26695/12479836.py in <module>
# ----> 1 test_font('handwriting')
#
# NameError: name 'test_font' is not defined

# %%
test_font('formal')
# Out:
# /var/folders/rk/cgmwyjj17ddfrn5d_vqzdyr00000gn/T/ipykernel_25796/2741756130.py:13: DeprecationWarning: getsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use getbbox or getlength instead.
#   text_height = font.getsize(font_name)[1] + 5
# <PIL.Image.Image image mode=RGB size=500x1500>
