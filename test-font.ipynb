# %%
from PIL import Image, ImageFont, ImageDraw
import os

# %%
def test_font(font_dir):
  image_width = 700
  image_height = 1500
  image = Image.new('RGB', (image_width, image_height,), '#fff')
  draw = ImageDraw.Draw(image)

  fonts = [f for f in os.listdir(font_dir) if f.endswith('.ttf')]
  fonts.sort()
  curr_y = 10
  for font_name in fonts:
    font = ImageFont.truetype(f'{font_dir}/{font_name}', 20)
    draw.text((10, curr_y), font_name + ' เก้าสิบห้าร้อยสามสิบ', font=font, fill='#000')
    text_height = font.getsize(font_name)[1] + 5
    curr_y += text_height
  return image

# %%
test_font('handwriting')
# Out:
# /var/folders/rk/cgmwyjj17ddfrn5d_vqzdyr00000gn/T/ipykernel_41816/1068684984.py:13: DeprecationWarning: getsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use getbbox or getlength instead.
#   text_height = font.getsize(font_name)[1] + 5
# <PIL.Image.Image image mode=RGB size=700x1500>

# %%
test_font('formal')
# Out:
# /var/folders/rk/cgmwyjj17ddfrn5d_vqzdyr00000gn/T/ipykernel_41816/1068684984.py:13: DeprecationWarning: getsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use getbbox or getlength instead.
#   text_height = font.getsize(font_name)[1] + 5
# <PIL.Image.Image image mode=RGB size=700x1500>

# %%
font = ImageFont.truetype('./formal/Surafont Naruto Italic.ttf', )
font.getbbox('เก้าสิบห้าร้อยสามสิบ')
# Out:
# (0, 3, 81, 12)

# %%
font = ImageFont.truetype('./formal/THSarabun.ttf', 24)
font.getbbox('เก้าสิบห้าร้อยสามสิบ')
# Out:
# (0, 5, 131, 21)

# %%
131
# Out:
# 194.39999999999998

# %%
10*24/195
# Out:
# 1.2307692307692308

# %%
195/24*1.23
# Out:
# 9.99375
