# %%
from PIL import Image, ImageFont, ImageDraw
import os

# %%
def test_font(font_dir):
  image_width = 700
  image_height = 5900
  image = Image.new('RGB', (image_width, image_height,), '#fff')
  draw = ImageDraw.Draw(image)

  fonts = [f for f in os.listdir(font_dir) if f.endswith('.ttf')]
  fonts.sort()
  curr_y = 10
  for font_name in fonts:
    font = ImageFont.truetype(f'{font_dir}/{font_name}', 20)
    text = font_name + ' เก้าสิบห้าร้อยสามสิบณฐชารย์'
    draw.text((10, curr_y), text, font=font, fill='#000')
    print(font_name)
    x0, y0, x1, y1 = draw.textbbox((10, curr_y), text, font=font)
    text_height = font.getsize(font_name)[1] + 5
    draw.rectangle((x0, y0, x1, y1), outline='#f00')
    curr_y += text_height
  return image

# %%
test_font('../fonts/handwriting')
# Out:
# -@-D-DekDee 2550 v.2.00-.ttf
# 1Laimue.ttf
# 2005_iannnnnDVD.ttf
# 2555 ed_crub KaiKea.ttf
# 5012_tLU_infection.ttf
# 5102_UEtuek_anamai.ttf
# 5104_UTUEK_WORAWIT.ttf
# BLK-Thai-Vi28.ttf
# Bangnampueng.ttf
# Bobby.ttf
# BooK_Handwrite[2006].ttf
# BrComfort.ttf
# BrComfortBold.ttf
# BrComfortThin.ttf
# BrCosmetic.ttf
# BrPineapple.ttf
# BrRomantic.ttf
# Br_goody.ttf
# Cloey.ttf
# Cutter.ttf
# DM Shining Star Regular.ttf
# FC Magic Italic.ttf
# FC Marshmallow Brush Italic.ttf
# FC Marshmallow Brush Regular.ttf
# /var/folders/rk/cgmwyjj17ddfrn5d_vqzdyr00000gn/T/ipykernel_65747/4255348054.py:16: DeprecationWarning: getsize is deprecated and will be removed in Pillow 10 (2023-07-01). Use getbbox or getlength instead.
#   text_height = font.getsize(font_name)[1] + 5
# FC Marshmallow Italic.ttf
# FC Marshmallow Regular.ttf
# FC PorRak Bold Italic.ttf
# FC PorRak Bold.ttf
# FC PorRak Italic.ttf
# FC PorRak Regular.ttf
# FC Rainbow Regular [Non-commercial use].ttf
# Friendly.ttf
# HappySaturday.ttf
# Henry.ttf
# Hioly.ttf
# Honey.ttf
# Jaiyen MSK.ttf
# JenjrusChan.ttf
# Joh-ney.ttf
# Jp Killtime.ttf
# KC Leftovers Plus.ttf
# KC Leftovers.ttf
# KanchaBranch.ttf
# KanchaHaha.ttf
# KanchaKancha.ttf
# KanchaNH.ttf
# KrazY_kid_2005.ttf
# LayijiMahaniyom-Bao-1.2.ttf
# Lonney.ttf
# MN FoiThong Bold Italic.ttf
# MN FoiThong Bold.ttf
# MN FoiThong Italic.ttf
# MN FoiThong.ttf
# MN KHAIPHALO Bold Italic.ttf
# MN KHAIPHALO Bold.ttf
# MN KHAIPHALO Italic.ttf
# MN KHAIPHALO.ttf
# MN Kha Ki Bold Italic.ttf
# MN Kha Ki Bold.ttf
# MN Kha Ki Italic.ttf
# MN Kha Ki.ttf
# MN Mamuang Nampla Wan Italic.ttf
# MN Mamuang Nampla Wan.ttf
# MN PANGPING Bold Italic.ttf
# MN PANGPING Bold.ttf
# MN PANGPING Italic.ttf
# MN PANGPING.ttf
# MN Pla Daek Italic.ttf
# MN Pla Daek.ttf
# MN SANGKHAYA Bold Italic.ttf
# MN SANGKHAYA Bold.ttf
# MN SANGKHAYA Italic.ttf
# MN SANGKHAYA.ttf
# MN Soda Bold Italic.ttf
# MN Soda Bold.ttf
# MN Soda Italic.ttf
# MN Soda.ttf
# MN-Mu-Deang-Bold-Italic.ttf
# MN-Mu-Deang-Bold.ttf
# MN-Mu-Deang-Italic.ttf
# MN-Mu-Deang-Light-Italic.ttf
# MN-Mu-Deang-Light.ttf
# MN-Mu-Deang.ttf
# MNNEasyread.ttf
# MiCranberry.ttf
# MiPie.ttf
# Mionie.ttf
# NURARADA-DEMOs.ttf
# NURARADA-jibiDEMO.ttf
# NURARADA-minigapDEMO.ttf
# NantatOO_1.1.1.ttf
# Nura133-thin.ttf
# Orawan HW.ttf
# PK Lampang Medium.ttf
# Parggar font.ttf
# Phoenix Rush.ttf
# Plump.ttf
# ReHoneyfly.ttf
# Remio.ttf
# SOV_BaanHook.ttf
# SOV_KhianKhao.ttf
# SOV_PaiNa-Bold.ttf
# SOV_PaiNa-BoldItalic.ttf
# SOV_PaiNa-Italic.ttf
# SOV_PaiNa.ttf
# SOV_PleanJai.ttf
# SOV_rataphan2498.ttf
# SP-Yok FFE-N.ttf
# SP-Yok N.ttf
# SP-Yok NC.ttf
# Samuel.ttf
# Simon.ttf
# SirakornHandina.ttf
# Surafont Sanukchang Italic.ttf
# Surafont Sanukchang Regular.ttf
# Surafont Sayamsuk Italic.ttf
# Surafont Sayamsuk Regular.ttf
# Tn_kaikia  1.001.ttf
# Tobie.ttf
# UID SALMON 2019 .ttf
# WR Hakmum Bold.ttf
# WR Hakmum.ttf
# WR Tish Kid.ttf
# WR Tish Kid2.ttf
# Whale.ttf
# can_NongAor.ttf
# fonttintin.ttf
# fonttintinver2update.ttf
# jp_Deknarok.ttf
# jp_converse.ttf
# kg_lecture.ttf
# maaja ver 1.00.ttf
# nura-kobsanam-thin.ttf
# nura-kobsanam-thinI.ttf
# nura-nongnui-ver.1-thin.ttf
# nura-nongnui-ver2-thin.ttf
# nura-nongnui-ver3-thin.ttf
# nura-nongnui-ver4-thin.ttf
# nura-sodsai-Italicbold.ttf
# nura-sodsai-thin.ttf
# nura-venom-regular.ttf
# nura-yoya-thin.ttf
# nura-yoya-thinS.ttf
# nurafahrung-thin.ttf
# puanpian.ttf
# rj-TIGER-Y-artschool.ttf
# rj-TIGER-Y-artschoolItalic.ttf
# rj-TIGER-Y-artschoolThin.ttf
# rj-TIGER-Y-artschoolThinitalic.ttf
# se-ed-patrawan-RJ.ttf
# se-ed-patrawanMO-RJ.ttf
# torsilp-wadkhen.ttf
# was@namchuemTEST.ttf
# <PIL.Image.Image image mode=RGB size=700x5900>

# %%
test_font('formal')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/rk/cgmwyjj17ddfrn5d_vqzdyr00000gn/T/ipykernel_65747/3642318819.py in <module>
# ----> 1 test_font('formal')
#
# /var/folders/rk/cgmwyjj17ddfrn5d_vqzdyr00000gn/T/ipykernel_65747/3605631968.py in test_font(font_dir)
#       5   draw = ImageDraw.Draw(image)
#       6
# ----> 7   fonts = [f for f in os.listdir(font_dir) if f.endswith('.ttf')]
#       8   fonts.sort()
#       9   curr_y = 10
#
# FileNotFoundError: [Errno 2] No such file or directory: 'formal'

# %%
font = ImageFont.truetype('./formal/Surafont Naruto Italic.ttf', )
font.getbbox('เก้าสิบห้าร้อยสามสิบ')
# Out:
# (0, 3, 81, 12)

# %%
font = ImageFont.truetype('./formal/THSarabun.ttf', 24)
font.getbbox('เก้าสิบห้าร้อยสามสิบ')
# Out:
# (0, 5, 131, 21)

# %%
131
# Out:
# 194.39999999999998

# %%
10*24/195
# Out:
# 1.2307692307692308

# %%
195/24*1.23
# Out:
# 9.99375
